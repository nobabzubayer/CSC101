# %%
#Creating a dictionary
contacts = {
    "Zubayer" : "1000",
    "Dipu" : "2000",
    "Niloy" : "3000"
}
#Adding new entry
contacts["Aman"] = "4000"

#updating the value of existing entry
contacts["Dipu"] = "5000"
#print key value pairs
for key,value in contacts.items():
  print(key,value)
# Out:
# Zubayer 1000
# Dipu 5000
# Niloy 3000
# Aman 4000
